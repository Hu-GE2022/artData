# %%
import time
import requests
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
import pandas as pd


from selenium import webdriver
from matplotlib import rc
from bs4 import BeautifulSoup
from urllib.request import urlopen
from selenium.webdriver.common.by import By

# %%
    wd = webdriver.Chrome('C:/Users/admin/Documents/GitHub/miniproject/StudyBigData/day03/chromedriver.exe') #경로 조심
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6908\1054557960.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   wd = webdriver.Chrome('C:/Users/admin/Documents/GitHub/miniproject/StudyBigData/day03/chromedriver.exe') #경로 조심

# %%
wd.get('https://map.naver.com/v5/bus/bus-station/?c=')

# %%
bus_stop = pd.read_csv('./data/bus_stop.csv', encoding='utf-8')
bus_stop
# Out:
#          NAME,C,254  LNG,N,19,15  LAT,N,19,15
# 0               동래역   129.077793    35.205960
# 1               동래역   129.078175    35.206061
# 2       동래고등학교(낙민역)   129.089512    35.200708
# 3       동래고등학교(낙민역)   129.089399    35.200654
# 4    안락동우체국(동해선안락역)   129.100713    35.197117
# 5    안락동우체국(동해선안락역)   129.100975    35.197213
# 6              동래한전   129.105215    35.196555
# 7              동래한전   129.106362    35.196355
# 8             부산원동역   129.112671    35.194551
# 9             부산원동역   129.112117    35.194371
# 10       수안역(동래교차로)   129.084477    35.201667
# 11       수안역(동래교차로)   129.083351    35.201927
# 12             동래한전   129.105215    35.196555
# 13             동래한전   129.106362    35.196355
# 14            부산원동역   129.112671    35.194551
# 15            부산원동역   129.112117    35.194371
# 16       수안역(동래교차로)   129.084477    35.201667
# 17       수안역(동래교차로)   129.083351    35.201927
# 18          원동IC교차로   129.118580    35.192935
# ...

# %%
bus_stop
# Out:
#                name
# 0               동래역
# 1       동래고등학교(낙민역)
# 2    안락동우체국(동해선안락역)
# 3              동래한전
# 4             부산원동역
# 5        수안역(동래교차로)
# 6           원동IC교차로
# 7   벡스코역.올림픽교차로환승센터
# 8            동해선재송역
# 9            해운대경찰서
# 10        동부지청어귀교차로
# 11           동해선센텀역
# 12           센텀고등학교
# 13            센텀센시빌
# 14          동해선벡스코역
# 15       올림픽교차로환승센터
# 16           올림픽교차로
# 17               운촌
# 18         해운대도시철도역
# 19       해운대구청어귀삼거리
# 20              동백역

# %%
bus_list = []

for i in bus_stop['name']:
    wd.get(f'https://map.naver.com/v5/bus/bus-station/{i}?c=')
    time.sleep(1)
    try:
        wd.find_element(By.XPATH, '//*[@id="container"]/shrinkable-layout/div/bus-home/div[1]/div/fusion-search-list/fusion-bus-station-list/div/fusion-bus-station-item[1]/div/div/div/div[1]').click() # 매장찾기 클릭해라
        time.sleep(2)
        req = wd.page_source
        soup = BeautifulSoup(req, "html.parser")
        for item in soup.find_all('strong', {'class': 'station_name'}):
            bus_list.append(item.str)
    except Exception as e:
        continue

print(bus_list)
# Out:
# [<strong _ngcontent-elx-c157="" class="station_name">46</strong>, <strong _ngcontent-elx-c157="" class="station_name">77</strong>, <strong _ngcontent-elx-c157="" class="station_name">100-1</strong>, <strong _ngcontent-elx-c157="" class="station_name">111-1</strong>, <strong _ngcontent-elx-c157="" class="station_name">121</strong>, <strong _ngcontent-elx-c157="" class="station_name">144</strong>, <strong _ngcontent-elx-c157="" class="station_name">148-1</strong>, <strong _ngcontent-elx-c157="" class="station_name">189</strong>, <strong _ngcontent-elx-c157="" class="station_name">210</strong>, <strong _ngcontent-elx-c157="" class="station_name">8</strong>, <strong _ngcontent-elx-c157="" class="station_name">1008</strong>, <strong _ngcontent-til-c157="" class="station_name">31</strong>, <strong _ngcontent-til-c157="" class="station_name">36</strong>, <strong _ngcontent-til-c157="" class="station_name">42</strong>, <strong _ngcontent-til-c157="" class="station_name">43</strong>, <strong 
# ...
